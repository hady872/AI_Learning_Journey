# %%
import pandas as pd

data = {
    "day": ["Sun", "Mon", "Tue", "Wed", "Thu"], 
    "price": [100, 105, 102, 110, 115],
    "volume": [1000, 1500, 1200, 2000, 2500]
}

df = pd.DataFrame(data)
df
# Out:
#    day  price  volume
# 0  Sun    100    1000
# 1  Mon    105    1500
# 2  Tue    102    1200
# 3  Wed    110    2000
# 4  Thu    115    2500

# %%
df["change"] = df["price"].diff
df["change_percent"] = df["price"].pct_change() * 100
df
# Out:
#    day  price  volume                                             change  \
# 0  Sun    100    1000  <bound method Series.diff of 0    100\n1    10...
# 1  Mon    105    1500  <bound method Series.diff of 0    100\n1    10...
# 2  Tue    102    1200  <bound method Series.diff of 0    100\n1    10...
# 3  Wed    110    2000  <bound method Series.diff of 0    100\n1    10...
# 4  Thu    115    2500  <bound method Series.diff of 0    100\n1    10...
#
#    change_percent
# 0             NaN
# 1        5.000000
# 2       -2.857143
# 3        7.843137
# 4        4.545455

# %%
df["price"].max()
# Out:
# np.int64(115)

# %%
df["price"].min()
# Out:
# np.int64(100)

# %%
import matplotlib.pyplot as plt

plt.plot(df["day"], df["price"], marker="o")

plt.title("Stock Price Movement")
plt.xlabel("Day")
plt.ylabel("Price")

plt.grid()
plt.show()

# %%
plt.bar(df["day"], df["volume"], color="green")

plt.title("Trending Volume")
plt.xlabel("Day")
plt.ylabel("volume")

plt.show()

# %%
df["ma_3"] = df["price"].rolling(3).mean()
df
# Out:
#    day  price  volume                                             change  \
# 0  Sun    100    1000  <bound method Series.diff of 0    100\n1    10...
# 1  Mon    105    1500  <bound method Series.diff of 0    100\n1    10...
# 2  Tue    102    1200  <bound method Series.diff of 0    100\n1    10...
# 3  Wed    110    2000  <bound method Series.diff of 0    100\n1    10...
# 4  Thu    115    2500  <bound method Series.diff of 0    100\n1    10...
#
#    change_percent        ma_3
# 0             NaN         NaN
# 1        5.000000         NaN
# 2       -2.857143  102.333333
# 3        7.843137  105.666667
# 4        4.545455  109.000000

# %%
plt.plot(df["day"], df["price"], marker="o", label="Price")
plt.plot(df["day"], df["ma_3"], linestyle="--", label="MA 3")

plt.legend()
plt.title("Price vs Moving Average")

plt.show()

# %%
import yfinance as yf
import pandas as pd

df = yf.download("AAPL", period="1mo")
df
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2026-03-02  264.720001  266.529999  260.200012  262.410004  41827900
# 2026-03-03  263.750000  265.559998  260.130005  263.480011  38568900
# 2026-03-04  262.519989  266.149994  261.420013  264.649994  39803100
# 2026-03-05  260.290009  261.559998  257.250000  260.790009  49658600
# 2026-03-06  257.459991  258.769989  254.369995  258.630005  41120000
# 2026-03-09  259.880005  261.149994  253.679993  255.690002  38218500
# 2026-03-10  260.829987  262.480011  256.950012  257.649994  30590800
# 2026-03-11  260.809998  262.130005  259.549988  261.089996  26218900
# 2026-03-12  255.759995  258.950012  254.179993  258.660004  40794000
# 2026-03-13  250.119995  256.329987  249.520004  255.479996  36930000
# 2026-03-16  252.820007  253.889999  249.880005  252.110001  32074200
# 2026-03-17  254.229996  255.130005  252.179993  252.960007  32361600
# 2026-03-18  249.940002  254.940002  249.000000  252.630005  35757900
# 2026-03-19  248.960007  251.830002  247.300003  249.399994  34864100
# 2026-03-20  247.990005  249.199997  246.000000  247.979996  88331100
# 2026-03-23  251.490005  254.600006  250.279999  253.970001  40546100
# 2026-03-24  251.639999  254.830002  249.550003  250.350006  45152300
# 2026-03-25  252.619995  255.000000  251.600006  254.100006  28476700
# 2026-03-26  252.889999  257.000000  250.770004  252.119995  41796700
# 2026-03-27  248.800003  255.490005  248.070007  253.899994  47842500

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))

plt.plot(df.index, df["Close"], label="Close Price")

plt.title("Apple Stock Price")
plt.xlabel("Data")
plt.ylabel("Price")

plt.legend()
plt.grid()

plt.show()

# %%
df["MA_5"] = df["Close"].rolling(5).mean()

plt.plot(df.index, df["Close"], label="Price")
plt.plot(df.index, df["MA_5"], label="MA 5")

plt.legend()
plt.show()

# %%
import yfinance as yf
import pandas as pd

df = yf.download("TSLA", period="1mo")
df
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume
# Ticker            TSLA        TSLA        TSLA        TSLA      TSLA
# Date
# 2026-03-02  403.320007  404.540009  388.250000  390.600006  55088300
# 2026-03-03  392.429993  396.339996  385.390015  395.089996  62617300
# 2026-03-04  405.940002  408.329987  394.579987  397.850006  68305500
# 2026-03-05  405.549988  408.619995  399.420013  401.570007  51925900
# 2026-03-06  396.730011  402.350006  394.209991  398.089996  64054600
# 2026-03-09  398.679993  401.589996  381.399994  390.049988  67018900
# 2026-03-10  399.239990  406.589996  398.190002  402.220001  59258700
# 2026-03-11  407.820007  416.380005  402.149994  402.279999  62559900
# 2026-03-12  395.010010  406.500000  394.649994  405.179993  60973800
# 2026-03-13  391.200012  400.200012  389.950012  399.170013  58504100
# 2026-03-16  395.559998  403.730011  394.420013  396.220001  58068300
# 2026-03-17  399.269989  400.119995  393.000000  395.690002  46890500
# 2026-03-18  392.779999  403.070007  392.309998  399.000000  50853100
# 2026-03-19  380.299988  387.269989  378.730011  387.269989  67078300
# 2026-03-20  367.959991  379.890015  364.459991  379.850006  78628600
# 2026-03-23  380.850006  385.329987  372.730011  373.089996  74606000
# 2026-03-24  383.029999  387.480011  376.309998  376.559998  60004900
# 2026-03-25  385.950012  396.230011  385.010010  389.989990  55157300
# 2026-03-26  372.109985  384.440002  371.869995  381.600006  55522900
# 2026-03-27  361.829987  369.859985  359.470001  369.690002  61869200

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))

plt.plot(df.index, df["Close"], label="Close Price")

plt.title("Apple Stock Price")
plt.xlabel("Data")
plt.ylabel("Price")

plt.legend()
plt.grid()

plt.show()

# %%
df["MA_5"] = df["Close"].rolling(5).mean()

plt.plot(df.index, df["Close"], label="Price")
plt.plot(df.index, df["MA_5"], label="MA 5")

plt.legend()
plt.show()
